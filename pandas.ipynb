# %%
#pandas 
""" 1. forming a pandas using series , dataframe
    2. data fetch , cleaning of data """

# %%
#series
import pandas as pd 
arr = [2,5,8,9]
b = pd.Series(arr)
print(b)
# Out:
# 0    2
# 1    5
# 2    8
# 3    9
# dtype: int64

# %%
import pandas as pd 
arr = [2,5,8,9]
b = pd.Series(arr, index = ("a","b","c","d"))
print(b)
# Out:
# a    2
# b    5
# c    8
# d    9
# dtype: int64

# %%
#data frame 
import pandas as pd 
arr = {"No" :[2,5,8,9],"Std" : [10,12,14,16]}
b = pd.DataFrame(arr)
print(b)
# Out:
#    No  Std
# 0   2   10
# 1   5   12
# 2   8   14
# 3   9   16

# %%
import pandas as pd 
arr = pd.read_csv("coffee_data.csv")
print(arr)
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# ...

# %%
import pandas as pd 
arr = pd.read_csv("coffee_data.csv")
print(arr.to_string())
# Out:
#            date             datetime cash_type  money                 coffee_name
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0                         Tea
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0                         Tea
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0                    Espresso
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0       Chocolate with coffee
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0         Chocolate with milk
# 5    2025-02-08  2025-02-08 18:55:30      card   33.0                    Espresso
# 6    2025-02-08  2025-02-08 18:59:03      cash   29.0   Coffee with Irish whiskey
# 7    2025-02-08  2025-02-08 19:00:28      cash   27.0     Irish whiskey with milk
# 8    2025-02-09  2025-02-09 08:45:45      card   28.0        Double Irish whiskey
# 9    2025-02-09  2025-02-09 10:41:36      cash   30.0       Chocolate with coffee
# ...

# %%
import pandas as pd 
arr = pd.read_csv("coffee_data.csv")
arr
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# ...

# %%
drop = arr.dropna()
print(drop)
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# ...

# %%
fill = arr.fillna(1)
print(fill)
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# ...
